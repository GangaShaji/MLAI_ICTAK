# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('/content/drive/MyDrive/Datasets MLAI/credit_card_default.csv')

# %%
data
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  \
# 0          1      20000    2          2         1   24      2      2     -1
# 1          2     120000    2          2         2   26     -1      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
# ...

# %%
data.shape
# Out:
# (30000, 25)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  int64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_1                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  int64
# ...

# %%
data.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.553667
# std     8660.398374   129747.661567      0.489129      0.790349      0.518326
# min        1.000000    10000.000000      1.000000      0.000000      1.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_1         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
data.isna().sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_1                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64

# %% [markdown]
# **no missing values**

# %%
data.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_1',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
sns.boxplot(data[['LIMIT_BAL']])
# Out:
# <Axes: >

# %%
sns.boxplot(data[['BILL_AMT1', 'BILL_AMT2',
       'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6']])
# Out:
# <Axes: >

# %%
sns.boxplot(data[['PAY_AMT1',
       'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6']])
# Out:
# <Axes: >

# %% [markdown]
# **Separating the dependent and independent variables**

# %%
x=data.drop('default payment next month',axis=1)
y=data['default payment next month']

# %%
data['default payment next month'].value_counts()
# Out:
# 0    23364
# 1     6636
# Name: default payment next month, dtype: int64

# %%
x.shape
# Out:
# (30000, 24)

# %%
y.shape
# Out:
# (30000,)

# %% [markdown]
# **SMOTE-Oversampling Technique to nullify data imbalance**

# %%
from imblearn.over_sampling import SMOTE

# Initialize SMOTE
smote = SMOTE(random_state=42)

# Apply SMOTE to the dataset to balance classes
x, y= smote.fit_resample(x, y)

# %%
x.shape
# Out:
# (46728, 24)

# %%
y.shape
# Out:
# (46728,)

# %% [markdown]
# **Feature Scaling-MinMax Scaler**

# %%
from sklearn.preprocessing import MinMaxScaler
minmax=MinMaxScaler()
x=minmax.fit_transform(x)

# %%
x
# Out:
# array([[0.00000000e+00, 1.01010101e-02, 1.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [3.33344445e-05, 1.11111111e-01, 1.00000000e+00, ...,
#         1.61030596e-03, 0.00000000e+00, 3.78310691e-03],
#        [6.66688890e-05, 8.08080808e-02, 1.00000000e+00, ...,
#         1.61030596e-03, 2.34450647e-03, 9.45776729e-03],
#        ...,
#        [3.42978099e-01, 2.30022222e-01, 0.00000000e+00, ...,
#         6.69243156e-03, 1.47352232e-02, 1.07534814e-02],
#        [8.29694323e-02, 2.53665657e-01, 1.00000000e+00, ...,
#         1.07407407e-03, 8.29955290e-04, 0.00000000e+00],
#        [2.74342478e-01, 4.43414141e-02, 1.00000000e+00, ...,
#         3.22061192e-03, 4.08178576e-03, 4.00252712e-03]])

# %%
x=pd.DataFrame(x)

# %% [markdown]
# **Splitting the data into train and test data**

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# **Logistic** **Regression Classifier**

# %%
from sklearn.linear_model import LogisticRegression
lr_reg=LogisticRegression()
lr_reg.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_predictions=lr_reg.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,confusion_matrix
print('Accuracy=',accuracy_score(y_predictions,y_test))
print('Precision',precision_score(y_predictions,y_test))
print('Recall=',recall_score(y_predictions,y_test))
print('f1-Score',f1_score(y_predictions,y_test))
confusion_matrix(y_predictions,y_test)
# Out:
# Accuracy= 0.7157072544404023
# Precision 0.700982486117044
# Recall= 0.7230667547918044
# f1-Score 0.7118533781585512
# array([[3407, 1400],
#        [1257, 3282]])

# %% [markdown]
# **KNN Classifier**

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
metric_k=[]
neighbors=np.arange(3,15)

# %%
for k in neighbors:
    classifier=KNeighborsClassifier(n_neighbors=k,metric='euclidean')
    classifier.fit(x_train,y_train)
    y_predictions=classifier.predict(x_test)
    acc=accuracy_score(y_test,y_predictions)
    metric_k.append(acc)

# %%
plt.plot(neighbors,metric_k,'o-')
plt.ylabel('Accuracy')
plt.xlabel('k')
plt.grid()

# %%
classifier=KNeighborsClassifier(n_neighbors=5,metric='euclidean')
classifier.fit(x_train,y_train)
y_predictions=classifier.predict(x_test)

# %%
print('Accuracy=',accuracy_score(y_predictions,y_test))
print('Precision',precision_score(y_predictions,y_test))
print('Recall=',recall_score(y_predictions,y_test))
print('f1-Score',f1_score(y_predictions,y_test))
confusion_matrix(y_predictions,y_test)
# Out:
# Accuracy= 0.7418146800770383
# Precision 0.7402819307988039
# Recall= 0.7432983058117092
# f1-Score 0.7417870518994114
# array([[3467, 1216],
#        [1197, 3466]])

# %% [markdown]
# **SVM Classifier**

# %%
from sklearn.svm import SVC
svmclf=SVC(kernel='linear')
svmclf.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
y_prediction=svmclf.predict(x_test)

# %%
print('Accuracy=',accuracy_score(y_predictions,y_test))
print('Precision',precision_score(y_predictions,y_test))
print('Recall=',recall_score(y_predictions,y_test))
print('f1-Score',f1_score(y_predictions,y_test))
confusion_matrix(y_predictions,y_test)
# Out:
# Accuracy= 0.7418146800770383
# Precision 0.7402819307988039
# Recall= 0.7432983058117092
# f1-Score 0.7417870518994114
# array([[3467, 1216],
#        [1197, 3466]])

# %% [markdown]
# **Decision Tree Classifier**

# %%
from sklearn.tree import DecisionTreeClassifier
dt_clf=DecisionTreeClassifier()
dt_clf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_prediction=dt_clf.predict(x_test)

# %%
print('Accuracy=',accuracy_score(y_predictions,y_test))
print('Precision',precision_score(y_predictions,y_test))
print('Recall=',recall_score(y_predictions,y_test))
print('f1-Score',f1_score(y_predictions,y_test))
confusion_matrix(y_predictions,y_test)
# Out:
# Accuracy= 0.7418146800770383
# Precision 0.7402819307988039
# Recall= 0.7432983058117092
# f1-Score 0.7417870518994114
# array([[3467, 1216],
#        [1197, 3466]])

# %% [markdown]
# **Random Forest Classifier**

# %%
from sklearn.ensemble import RandomForestClassifier
rf_clf=RandomForestClassifier()
rf_clf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_predictions=rf_clf.predict(x_test)

# %%
print('Accuracy=',accuracy_score(y_test,y_predictions))
print('Precision=',precision_score(y_test,y_predictions,average='weighted'))
print('recall_score=',recall_score(y_test,y_predictions,average='weighted'))
print('f1_score=',f1_score(y_test,y_predictions,average='weighted'))
confusion_matrix(y_test,y_predictions)
# Out:
# Accuracy= 0.7418146800770383
# Precision= 0.7418206994853148
# recall_score= 0.7418146800770383
# f1_score= 0.7418146239161978
# array([[3467, 1197],
#        [1216, 3466]])

# %% [markdown]
# **Gradient Boost Classifier**

# %%
from sklearn.ensemble import GradientBoostingClassifier
gb=GradientBoostingClassifier()
gb.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier()

# %%
y_predictions=gb.predict(x_test)

# %%
print('Accuracy=',accuracy_score(y_test,y_predictions))
print('Precision=',precision_score(y_test,y_predictions,average='weighted'))
print('recall_score=',recall_score(y_test,y_predictions,average='weighted'))
print('f1_score=',f1_score(y_test,y_predictions,average='weighted'))
confusion_matrix(y_test,y_predictions)
# Out:
# Accuracy= 0.7818317997004066
# Precision= 0.7840871908022271
# recall_score= 0.7818317997004065
# f1_score= 0.7814236086337157
# array([[3851,  813],
#        [1226, 3456]])

# %% [markdown]
# **LGBoost Algorithm**

# %%
! pip install lightgbm

# %%
from lightgbm import LGBMClassifier

# %%
lgbc=LGBMClassifier()
lgbc.fit(x_train,y_train)
# Out:
# [LightGBM] [Info] Number of positive: 18682, number of negative: 18700
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003456 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3695
# [LightGBM] [Info] Number of data points in the train set: 37382, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499759 -> initscore=-0.000963
# [LightGBM] [Info] Start training from score -0.000963
# LGBMClassifier()

# %%
y_predictions=lgbc.predict(x_test)

# %%
print('Accuracy=',accuracy_score(y_test,y_predictions))
print('Precision=',precision_score(y_test,y_predictions,average='weighted'))
print('recall_score=',recall_score(y_test,y_predictions,average='weighted'))
print('f1_score=',f1_score(y_test,y_predictions,average='weighted'))
confusion_matrix(y_test,y_predictions)
# Out:
# Accuracy= 0.8100791782580783
# Precision= 0.8131350645155435
# recall_score= 0.8100791782580783
# f1_score= 0.8096380749207647
# array([[4006,  658],
#        [1117, 3565]])

# %% [markdown]
# **Hypertuning using OPTUNA**

# %%
# !pip install optuna
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.6/409.6 kB 4.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.8/226.8 kB 19.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 7.2 MB/s eta 0:00:00
# ...

# %%
import sklearn
def objective(trial):
      n_estimators = trial.suggest_int('n_estimators', 100, 1600)
      max_depth=trial.suggest_int('max_depth',10,500)
      num_leaves=trial.suggest_int('num_leaves',10,500)
      lgbc= LGBMClassifier(n_estimators=n_estimators,max_depth=max_depth,num_leaves=num_leaves)
      return sklearn.model_selection.cross_val_score(rf_clf,x,y,n_jobs=-1, cv=3).mean()

# %%
import optuna
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50)
# Out:
# [I 2023-11-08 09:50:08,522] A new study created in memory with name: no-name-9256e4c5-3ca5-4380-b3f8-aac90474231e
# [I 2023-11-08 09:50:45,208] Trial 0 finished with value: 0.4115947611710324 and parameters: {'n_estimators': 1248, 'max_depth': 222, 'num_leaves': 426}. Best is trial 0 with value: 0.4115947611710324.
# [I 2023-11-08 09:51:13,302] Trial 1 finished with value: 0.41574644752610856 and parameters: {'n_estimators': 305, 'max_depth': 331, 'num_leaves': 178}. Best is trial 1 with value: 0.41574644752610856.
# [I 2023-11-08 09:51:40,795] Trial 2 finished with value: 0.4133709981167608 and parameters: {'n_estimators': 1014, 'max_depth': 430, 'num_leaves': 259}. Best is trial 1 with value: 0.41574644752610856.
# [I 2023-11-08 09:52:08,262] Trial 3 finished with value: 0.4145694230439993 and parameters: {'n_estimators': 1289, 'max_depth': 18, 'num_leaves': 141}. Best is trial 1 with value: 0.41574644752610856.
# ...

# %%
trial = study.best_trial
print('Accuracy: {}'.format(trial.value))
print("Best hyperparameters: {}".format(trial.params))
# Out:
# Accuracy: 0.4167308680020545
# Best hyperparameters: {'n_estimators': 1349, 'max_depth': 464, 'num_leaves': 73}

# %%
lgbc= LGBMClassifier(n_estimators=1349,max_depth=464,num_leaves=73)

# %%
lgbc.fit(x_train,y_train)
# Out:
# [LightGBM] [Info] Number of positive: 18682, number of negative: 18700
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.006045 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3695
# [LightGBM] [Info] Number of data points in the train set: 37382, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499759 -> initscore=-0.000963
# [LightGBM] [Info] Start training from score -0.000963
# LGBMClassifier(max_depth=464, n_estimators=1349, num_leaves=73)

# %%
y_predictions=lgbc.predict(x_test)

# %%
print('Accuracy=',accuracy_score(y_test,y_predictions))
print('Precision=',precision_score(y_test,y_predictions,average='weighted'))
print('recall_score=',recall_score(y_test,y_predictions,average='weighted'))
print('f1_score=',f1_score(y_test,y_predictions,average='weighted'))
confusion_matrix(y_test,y_predictions)
# Out:
# Accuracy= 0.8686068906484057
# Precision= 0.8697301382957833
# recall_score= 0.8686068906484057
# f1_score= 0.868515180016572
# array([[4178,  486],
#        [ 742, 3940]])

# %% [markdown]
# **AdaBoost Classifier**

# %%
from sklearn.ensemble import AdaBoostClassifier
ada=AdaBoostClassifier()
ada.fit(x_train,y_train)
# Out:
# AdaBoostClassifier()

# %%
y_predictions = ada.predict(x_test)

# %%
print('Accuracy=',accuracy_score(y_test,y_predictions))
print('Precision=',precision_score(y_test,y_predictions,average='weighted'))
print('recall_score=',recall_score(y_test,y_predictions,average='weighted'))
print('f1_score=',f1_score(y_test,y_predictions,average='weighted'))
confusion_matrix(y_test,y_predictions)
# Out:
# Accuracy= 0.7529424352664241
# Precision= 0.7537117258061076
# recall_score= 0.7529424352664241
# f1_score= 0.7527741641202699
# array([[3636, 1028],
#        [1281, 3401]])

# %% [markdown]
# **XGBoost Classifier**

# %%
! pip install xgboost

# %%
from xgboost import XGBClassifier

# %%
xgbc=XGBClassifier()

# %%
xgbc.fit(x_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
y_predictions=xgbc.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,confusion_matrix
print('Accuracy=',accuracy_score(y_test,y_predictions))
print('Precision=',precision_score(y_test,y_predictions,average='weighted'))
print('recall_score=',recall_score(y_test,y_predictions,average='weighted'))
print('f1_score=',f1_score(y_test,y_predictions,average='weighted'))
confusion_matrix(y_test,y_predictions)
# Out:
# Accuracy= 0.8290177616092446
# Precision= 0.8306495078160854
# recall_score= 0.8290177616092446
# f1_score= 0.8288210003091975
# array([[4028,  636],
#        [ 962, 3720]])

# %% [markdown]
# **Hyper Parameter Optimization using OPTUNA**

# %%
# !pip install optuna
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.6/409.6 kB 4.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.8/226.8 kB 7.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 7.5 MB/s eta 0:00:00
# ...

# %%
import sklearn
def objective(trial):
      n_estimators = trial.suggest_int('n_estimators', 100, 1600)
      max_depth=trial.suggest_int('max_depth',10,500)
      min_child_weight=trial.suggest_int('min_child_weight',1,5)
      xgb = XGBClassifier(n_estimators=n_estimators,max_depth=max_depth,min_child_weight=min_child_weight)
      return sklearn.model_selection.cross_val_score(xgb,x,y,n_jobs=-1, cv=3).mean()

# %%
import optuna
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50)
# Out:
# [I 2023-11-09 06:41:09,204] A new study created in memory with name: no-name-e0a0c52e-8ef7-4460-a2ce-c17085c946d5
# [I 2023-11-09 06:42:00,961] Trial 0 finished with value: 0.417929292929293 and parameters: {'n_estimators': 1281, 'max_depth': 333, 'min_child_weight': 5}. Best is trial 0 with value: 0.417929292929293.
# [I 2023-11-09 06:42:44,043] Trial 1 finished with value: 0.4169020715630885 and parameters: {'n_estimators': 1315, 'max_depth': 153, 'min_child_weight': 3}. Best is trial 0 with value: 0.417929292929293.
# [I 2023-11-09 06:43:11,659] Trial 2 finished with value: 0.4160674542030474 and parameters: {'n_estimators': 509, 'max_depth': 100, 'min_child_weight': 3}. Best is trial 0 with value: 0.417929292929293.
# [I 2023-11-09 06:43:46,587] Trial 3 finished with value: 0.41735148091080293 and parameters: {'n_estimators': 1047, 'max_depth': 22, 'min_child_weight': 5}. Best is trial 0 with value: 0.417929292929293.
# ...

# %%
trial = study.best_trial
print('Accuracy: {}'.format(trial.value))
print("Best hyperparameters: {}".format(trial.params))
# Out:
# Accuracy: 0.4209253552473891
# Best hyperparameters: {'n_estimators': 1401, 'max_depth': 11, 'min_child_weight': 4}

# %%
xgbc=XGBClassifier(n_estimators=1401,max_depth=11,min_child_weight=4)

# %%
xgbc.fit(x_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=11, max_leaves=None,
#               min_child_weight=4, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=1401, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
y_predictions=xgbc.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,confusion_matrix
print('Accuracy=',accuracy_score(y_test,y_predictions))
print('Precision=',precision_score(y_test,y_predictions,average='weighted'))
print('recall_score=',recall_score(y_test,y_predictions,average='weighted'))
print('f1_score=',f1_score(y_test,y_predictions,average='weighted'))
confusion_matrix(y_test,y_predictions)
# Out:
# Accuracy= 0.8571581425208645
# Precision= 0.857550392818431
# recall_score= 0.8571581425208645
# f1_score= 0.8571243578447781
# array([[4073,  591],
#        [ 744, 3938]])

# %% [markdown]
# **Best Model-LGBoost Classifier**

# %% [markdown]
# **Accuracy= 0.8686068906484057**
#
# **Precision= 0.8697301382957833**
#
# **recall_score= 0.8686068906484057**
#
# **f1_score= 0.868515180016572**
#
# confusion matrix
#
# ([[4178,  486],
#
#   [ 742, 3940]])
